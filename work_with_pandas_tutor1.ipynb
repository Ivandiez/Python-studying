# %%
# render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# pd.set_option('display.mpl_style', 'default') # make the graphs a bit prettier
plt.rcParams["figure.figsize"] = (15, 5)

# %%
broken_df = pd.read_csv('comptage_velo_2018.csv')
broken_df[:3]
# Out:
#          Date Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# 0  01/01/2018      00:00      29     30     18.0        2                8.0
# 1  02/01/2018      00:00      94     71     32.0        0                6.0
# 2  03/01/2018      00:00     200    149     54.0        0               30.0
#
#    CSC (Côte Sainte-Catherine)  Eco-Display Parc Stanley  \
# 0                            7                       NaN
# 1                           23                       NaN
# 2                           58                       NaN
#
#    Eco-Totem - Métro Laurier  ...  Parc  PierDup  Pont Jacques-Cartier  \
# 0                         52  ...    15        0                   8.0
# 1                         78  ...    38        0                   5.0
# 2                        112  ...    76        4                   9.0
#
#    Rachel / Hôtel de Ville  Rachel / Papineau  René-Lévesque  Saint-Antoine  \
# ...

# %%
fixed_df = pd.read_csv("comptage_velo_2018.csv", encoding="latin1", parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
#            Unnamed: 1  Berri1  Boyer  Boyer 2  BrÃ©beuf  Christophe-Colomb  \
# Date
# 2018-01-01      00:00      29     30     18.0         2                8.0
# 2018-01-02      00:00      94     71     32.0         0                6.0
# 2018-01-03      00:00     200    149     54.0         0               30.0
#
#             CSC (CÃ´te Sainte-Catherine)  Eco-Display Parc Stanley  \
# Date
# 2018-01-01                             7                       NaN
# 2018-01-02                            23                       NaN
# 2018-01-03                            58                       NaN
#
#             Eco-Totem - MÃ©tro Laurier  Edmond Valade  ...  Parc  PierDup  \
# Date                                                   ...
# 2018-01-01                          52              0  ...    15        0
# 2018-01-02                          78              0  ...    38        0
# 2018-01-03                         112              0  ...    76        4
#
# ...

# %%
fixed_df["Berri1"]
# Out:
# Date
# 2018-01-01     29
# 2018-01-02     94
# 2018-01-03    200
# 2018-01-04    230
# 2018-01-05    125
#              ...
# 2018-12-27    177
# 2018-12-28    103
# 2018-12-29    103
# 2018-12-30    112
# 2018-12-31     95
# Name: Berri1, Length: 365, dtype: int64

# %%
fixed_df["Berri1"].plot()

# %%
fixed_df.plot(figsize=(15, 10))

# %%
df = pd.read_csv('comptage_velo_2018.csv', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df['Berri1'].plot()
